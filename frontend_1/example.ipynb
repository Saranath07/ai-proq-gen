# %%
from run import run_code

# %%
code = '''
print("hello")
'''

# %%
test_cases = [{"input": "print('world')", "output" : ""}]

# %%
run_code(code, test_cases, input_type = "code")
# Out:
# [{'input': "print('world')", 'output': ''}]
# {'actual_output': ['hello\nTraceback (most recent call last):\n  File "/piston/jobs/7f24b3ec-cd62-4aa7-9c33-2413f73ebd14/script.py", line 4, in <module>\n    import sys; exec(sys.stdin.read())\n  File "<string>", line 1, in <module>\nNameError: name \'code\' is not defined'],
#  'expected_output': ['']}
